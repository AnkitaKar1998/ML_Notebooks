# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ankita\\Desktop\\ML\\Iris'

# %%
import pandas as pd

# %%
iris_csv = pd.read_csv('iris.csv')

# %%
iris_csv
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
iris_csv.isna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# 5           False        False         False        False    False
# 6           False        False         False        False    False
# 7           False        False         False        False    False
# 8           False        False         False        False    False
# 9           False        False         False        False    False
# 10          False        False         False        False    False
# 11          False        False         False        False    False
# 12          False        False         False        False    False
# ...

# %%
import xlrd as xl

# %%
iris_xlsx = pd.read_excel('iris.xlsx')

# %%
iris_xlsx
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
iris_txt = pd.read_table("iris.txt")
# Out:
# C:\Users\Ankita\Python 3.7.2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
iris_txt
# Out:
#     sepal.length,"sepal.width","petal.length","petal.width","variety"
# 0                              5.1,3.5,1.4,.2,"Setosa"
# 1                                4.9,3,1.4,.2,"Setosa"
# 2                              4.7,3.2,1.3,.2,"Setosa"
# 3                              4.6,3.1,1.5,.2,"Setosa"
# 4                                5,3.6,1.4,.2,"Setosa"
# 5                              5.4,3.9,1.7,.4,"Setosa"
# 6                              4.6,3.4,1.4,.3,"Setosa"
# 7                                5,3.4,1.5,.2,"Setosa"
# 8                              4.4,2.9,1.4,.2,"Setosa"
# 9                              4.9,3.1,1.5,.1,"Setosa"
# 10                             5.4,3.7,1.5,.2,"Setosa"
# 11                             4.8,3.4,1.6,.2,"Setosa"
# 12                               4.8,3,1.4,.1,"Setosa"
# 13                               4.3,3,1.1,.1,"Setosa"
# 14                               5.8,4,1.2,.2,"Setosa"
# 15                             5.7,4.4,1.5,.4,"Setosa"
# ...

# %%
iris_txt = pd.read_table("iris.txt", delimiter=",")
# Out:
# C:\Users\Ankita\Python 3.7.2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
iris_txt
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %% [markdown]
# Reading txt file through read_csv() method.

# %%
iris_txt = pd.read_csv("iris.txt", delimiter=",")

# %%
iris_txt
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
shallow_iris = iris_csv.copy(deep=False)

# %%
deep_rirs = iris_csv.copy(deep=True)

# %%
iris_csv.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris_csv.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris_csv.size
# Out:
# 750

# %%
iris_csv.shape
# Out:
# (150, 5)

# %%
iris_csv.memory_usage()
# Out:
# Index             40
# sepal.length    1200
# sepal.width     1200
# petal.length    1200
# petal.width     1200
# variety          600
# dtype: int64

# %%
iris_csv.ndim
# Out:
# 2

# %%
iris_csv.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
iris_csv.tail(6)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris_csv.loc[3]
# Out:
# sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 3, dtype: object

# %%
iris_csv.iloc[3]
# Out:
# sepal.length       4.6
# sepal.width        3.1
# petal.length       1.5
# petal.width        0.2
# variety         Setosa
# Name: 3, dtype: object

# %%
iris_csv.loc[iris_csv['sepal.length']>5]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 10            5.4          3.7           1.5          0.2      Setosa
# 14            5.8          4.0           1.2          0.2      Setosa
# 15            5.7          4.4           1.5          0.4      Setosa
# 16            5.4          3.9           1.3          0.4      Setosa
# 17            5.1          3.5           1.4          0.3      Setosa
# 18            5.7          3.8           1.7          0.3      Setosa
# 19            5.1          3.8           1.5          0.3      Setosa
# 20            5.4          3.4           1.7          0.2      Setosa
# 21            5.1          3.7           1.5          0.4      Setosa
# 23            5.1          3.3           1.7          0.5      Setosa
# ...

# %%
iris_csv.iloc[5:13]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa

# %%
iris_csv.loc[5:8,['sepal.length','petal.width']]
# Out:
#    sepal.length  petal.width
# 5           5.4          0.4
# 6           4.6          0.3
# 7           5.0          0.2
# 8           4.4          0.2

# %%
iris_csv.at[5,'sepal.length']
# Out:
# 5.4

# %%
iris_csv.iat[5,2]
# Out:
# 1.7

# %%
iris_csv.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
iris_csv.select_dtypes(include=[object], exclude=[None])
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# 5       Setosa
# 6       Setosa
# 7       Setosa
# 8       Setosa
# 9       Setosa
# 10      Setosa
# 11      Setosa
# 12      Setosa
# 13      Setosa
# 14      Setosa
# 15      Setosa
# 16      Setosa
# 17      Setosa
# 18      Setosa
# 19      Setosa
# 20      Setosa
# 21      Setosa
# 22      Setosa
# 23      Setosa
# 24      Setosa
# 25      Setosa
# 26      Setosa
# 27      Setosa
# 28      Setosa
# 29      Setosa
# ..         ...
# 120  Virginica
# 121  Virginica
# 122  Virginica
# 123  Virginica
# 124  Virginica
# 125  Virginica
# 126  Virginica
# 127  Virginica
# 128  Virginica
# 129  Virginica
# 130  Virginica
# 131  Virginica
# 132  Virginica
# 133  Virginica
# 134  Virginica
# 135  Virginica
# 136  Virginica
# 137  Virginica
# 138  Virginica
# 139  Virginica
# 140  Virginica
# 141  Virginica
# 142  Virginica
# 143  Virginica
# 144  Virginica
# 145  Virginica
# ...

# %%
iris_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# petal.length    150 non-null float64
# petal.width     150 non-null float64
# variety         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
import numpy as np

# %%
np.unique(iris_csv['sepal.length'])
# Out:
# array([4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9, 5. , 5.1, 5.2, 5.3, 5.4, 5.5,
#        5.6, 5.7, 5.8, 5.9, 6. , 6.1, 6.2, 6.3, 6.4, 6.5, 6.6, 6.7, 6.8,
#        6.9, 7. , 7.1, 7.2, 7.3, 7.4, 7.6, 7.7, 7.9])

# %%
iris_csv['sepal.length'].astype('object')
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4        5
# 5      5.4
# 6      4.6
# 7        5
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25       5
# 26       5
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138      6
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: object

# %%
iris_csv.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
cars_data=pd.read_csv("toyota.csv",na_values=["??","????"])

# %%
cars_data.isna().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
pd.crosstab(index=cars_data["FuelType"],columns="count", dropna=True)
# Out:
# col_0     count
# FuelType
# CNG          17
# Diesel      155
# Petrol     1264

# %%
pd.crosstab(index=cars_data["Doors"], columns=cars_data["FuelType"],dropna=True)
# Out:
# FuelType  CNG  Diesel  Petrol
# Doors
# 2           0       1       1
# 3           6      61     555
# 4           3      14     121
# 5           8      79     587

# %%
pd.crosstab(index=cars_data["Automatic"], columns=cars_data["FuelType"],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           16     155    1185
# 1            1       0      79

# %%
df1=pd.read_csv("crashTest_TrainData.csv")

# %%
df2=pd.read_csv("crashTest_TestData.csv")

# %%
df1.describe()
# Out:
#          CarID      ManHI      ManBI       IntI      HVACi    Safety
# count  80.0000  80.000000  80.000000  77.000000  80.000000  80.00000
# mean   40.5000  -0.093500  -0.927750  -0.346623   0.119750   0.54375
# std    23.2379   5.802878   5.600224   5.806723   5.813306   5.79723
# min     1.0000  -9.930000  -9.940000  -9.990000  -9.820000  -9.80000
# 25%    20.7500  -5.195000  -5.705000  -5.940000  -5.675000  -4.67750
# 50%    40.5000   0.635000  -1.815000  -0.500000   0.870000   0.83000
# 75%    60.2500   5.050000   3.417500   4.820000   5.062500   4.62250
# max    80.0000   9.570000   9.610000   9.720000   9.890000   9.99000

# %%
df2.describe()
# Out:
#            CarID      ManHI     ManBI       IntI      HVACi     Safety
# count   20.00000  20.000000  20.00000  20.000000  20.000000  20.000000
# mean    90.50000   0.047000   0.32800   0.524000   0.723500   0.191000
# std      5.91608   6.253216   4.05164   4.953771   5.479129   6.154548
# min     81.00000  -9.940000  -8.74000  -8.950000  -9.230000  -8.660000
# 25%     85.75000  -5.535000  -2.50250  -3.272500  -2.455000  -6.095000
# 50%     90.50000   0.740000   0.67000   1.200000   0.675000  -0.770000
# 75%     95.25000   5.110000   2.50000   3.907500   5.337500   4.992500
# max    100.00000   9.090000   8.42000   8.870000   8.330000   9.620000

# %%
df1["CarType"].value_counts()
# Out:
# Hatchback    50
# SUV          30
# Name: CarType, dtype: int64

# %%
df2["CarType"].value_counts()
# Out:
# Hatchback    10
# SUV          10
# Name: CarType, dtype: int64

# %%
df1.isnull().sum()
# Out:
# CarID      0
# ManHI      0
# ManBI      0
# IntI       3
# HVACi      0
# Safety     0
# CarType    0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# CarID      0
# ManHI      0
# ManBI      0
# IntI       3
# HVACi      0
# Safety     0
# CarType    0
# dtype: int64

# %% [markdown]
# New Assignment

# %%
Train_Data=pd.read_csv("CrashTest_TrainData.csv")

# %%
Test_Data=pd.read_csv("CrashTest_TestData.csv")

# %%
Train_Data.isnull()
# Out:
#     CarID  ManHI  ManBI   IntI  HVACi  Safety  CarType
# 0   False  False  False  False  False   False    False
# 1   False  False  False  False  False   False    False
# 2   False  False  False  False  False   False    False
# 3   False  False  False  False  False   False    False
# 4   False  False  False  False  False   False    False
# 5   False  False  False  False  False   False    False
# 6   False  False  False  False  False   False    False
# 7   False  False  False  False  False   False    False
# 8   False  False  False  False  False   False    False
# 9   False  False  False  False  False   False    False
# 10  False  False  False  False  False   False    False
# 11  False  False  False  False  False   False    False
# 12  False  False  False  False  False   False    False
# 13  False  False  False  False  False   False    False
# 14  False  False  False   True  False   False    False
# 15  False  False  False  False  False   False    False
# ...

# %%
Train_Data.isna()
# Out:
#     CarID  ManHI  ManBI   IntI  HVACi  Safety  CarType
# 0   False  False  False  False  False   False    False
# 1   False  False  False  False  False   False    False
# 2   False  False  False  False  False   False    False
# 3   False  False  False  False  False   False    False
# 4   False  False  False  False  False   False    False
# 5   False  False  False  False  False   False    False
# 6   False  False  False  False  False   False    False
# 7   False  False  False  False  False   False    False
# 8   False  False  False  False  False   False    False
# 9   False  False  False  False  False   False    False
# 10  False  False  False  False  False   False    False
# 11  False  False  False  False  False   False    False
# 12  False  False  False  False  False   False    False
# 13  False  False  False  False  False   False    False
# 14  False  False  False   True  False   False    False
# 15  False  False  False  False  False   False    False
# ...

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
data=Train_Data.copy()

# %%
data.describe()
# Out:
#          CarID      ManHI      ManBI       IntI      HVACi    Safety
# count  80.0000  80.000000  80.000000  77.000000  80.000000  80.00000
# mean   40.5000  -0.093500  -0.927750  -0.346623   0.119750   0.54375
# std    23.2379   5.802878   5.600224   5.806723   5.813306   5.79723
# min     1.0000  -9.930000  -9.940000  -9.990000  -9.820000  -9.80000
# 25%    20.7500  -5.195000  -5.705000  -5.940000  -5.675000  -4.67750
# 50%    40.5000   0.635000  -1.815000  -0.500000   0.870000   0.83000
# 75%    60.2500   5.050000   3.417500   4.820000   5.062500   4.62250
# max    80.0000   9.570000   9.610000   9.720000   9.890000   9.99000

# %%
data.describe(include="float")
# Out:
#            ManHI      ManBI       IntI      HVACi    Safety
# count  80.000000  80.000000  77.000000  80.000000  80.00000
# mean   -0.093500  -0.927750  -0.346623   0.119750   0.54375
# std     5.802878   5.600224   5.806723   5.813306   5.79723
# min    -9.930000  -9.940000  -9.990000  -9.820000  -9.80000
# 25%    -5.195000  -5.705000  -5.940000  -5.675000  -4.67750
# 50%     0.635000  -1.815000  -0.500000   0.870000   0.83000
# 75%     5.050000   3.417500   4.820000   5.062500   4.62250
# max     9.570000   9.610000   9.720000   9.890000   9.99000

# %%
data.describe(include="object")
# Out:
#           CarType
# count          80
# unique          2
# top     Hatchback
# freq           50

# %%
data.describe(include="O")
# Out:
#           CarType
# count          80
# unique          2
# top     Hatchback
# freq           50

# %%
data['CarType'].value_counts()
# Out:
# Hatchback    50
# SUV          30
# Name: CarType, dtype: int64

# %%
data['IntI']
# Out:
# 0     2.86
# 1     9.72
# 2    -7.61
# 3     0.92
# 4    -4.15
# 5     0.83
# 6    -6.65
# 7    -6.85
# 8     8.10
# 9     0.27
# 10   -4.68
# 11   -6.06
# 12   -9.38
# 13    7.85
# 14     NaN
# 15    5.77
# 16   -2.94
# 17   -3.68
# 18   -8.01
# 19    2.86
# 20   -9.99
# 21     NaN
# 22    3.70
# 23   -7.48
# 24   -7.00
# 25   -0.41
# 26    4.67
# 27   -1.93
# 28    9.36
# 29    0.73
#       ...
# 50    6.23
# 51    6.07
# 52    8.48
# 53    2.25
# 54   -1.38
# 55    8.55
# 56   -7.49
# 57   -7.58
# 58    7.95
# 59   -0.42
# 60    5.41
# 61    5.74
# 62    1.57
# 63    8.76
# 64    4.02
# 65   -3.63
# 66   -7.52
# 67    8.38
# 68   -7.10
# 69    5.61
# 70   -7.98
# 71    9.58
# 72   -3.22
# 73    6.47
# 74   -7.74
# 75   -2.12
# 76   -2.65
# 77   -5.45
# 78   -2.13
# 79    1.57
# Name: IntI, Length: 80, dtype: float64

# %%
data.dropna()
# Out:
#     CarID  ManHI  ManBI  IntI  HVACi  Safety    CarType
# 0       1  -5.27  -1.30  2.86  -4.85    4.04        SUV
# 1       2  -4.82  -5.38  9.72  -0.97   -4.57  Hatchback
# 2       3   9.57  -7.50 -7.61   1.33   -5.10  Hatchback
# 3       4   2.84  -2.85  0.92   5.51   -6.64  Hatchback
# 4       5   0.00   2.68 -4.15   0.85    5.58        SUV
# 5       6   0.40   6.34  0.83   5.03   -8.10        SUV
# 6       7   5.94   3.14 -6.65   6.62   -1.32  Hatchback
# 7       8   5.78  -1.75 -6.85   0.73    5.50  Hatchback
# 8       9   0.86  -4.32  8.10  -8.96    3.10  Hatchback
# 9      10   7.36   7.42  0.27  -8.62    3.08        SUV
# 10     11  -7.95  -6.44 -4.68   3.86    9.82  Hatchback
# 11     12  -1.75  -8.09 -6.06  -9.13   -6.45        SUV
# 12     13   9.44  -0.02 -9.38   0.06    6.06        SUV
# 13     14  -9.67   9.61  7.85   5.88   -8.14  Hatchback
# 15     16  -9.93  -6.15  5.77   8.76    3.60  Hatchback
# 16     17   3.16  -6.80 -2.94   1.83    8.36  Hatchback
# ...

# %%
#gives correlation
data.corr()
# Out:
#            CarID     ManHI     ManBI      IntI     HVACi    Safety
# CarID   1.000000 -0.145632  0.107529  0.076919  0.106891  0.011986
# ManHI  -0.145632  1.000000  0.081582 -0.087643 -0.164935  0.018466
# ManBI   0.107529  0.081582  1.000000 -0.096270  0.143497 -0.122126
# IntI    0.076919 -0.087643 -0.096270  1.000000 -0.098272 -0.155162
# HVACi   0.106891 -0.164935  0.143497 -0.098272  1.000000  0.020642
# Safety  0.011986  0.018466 -0.122126 -0.155162  0.020642  1.000000

# %%
data["CarType"].value_counts()
# Out:
# Hatchback    50
# SUV          30
# Name: CarType, dtype: int64

# %%
#converts categorical data dummy variable
pd.get_dummies(data,columns=["CarType"])
# Out:
#     CarID  ManHI  ManBI  IntI  HVACi  Safety  CarType_Hatchback  CarType_SUV
# 0       1  -5.27  -1.30  2.86  -4.85    4.04                  0            1
# 1       2  -4.82  -5.38  9.72  -0.97   -4.57                  1            0
# 2       3   9.57  -7.50 -7.61   1.33   -5.10                  1            0
# 3       4   2.84  -2.85  0.92   5.51   -6.64                  1            0
# 4       5   0.00   2.68 -4.15   0.85    5.58                  0            1
# 5       6   0.40   6.34  0.83   5.03   -8.10                  0            1
# 6       7   5.94   3.14 -6.65   6.62   -1.32                  1            0
# 7       8   5.78  -1.75 -6.85   0.73    5.50                  1            0
# 8       9   0.86  -4.32  8.10  -8.96    3.10                  1            0
# 9      10   7.36   7.42  0.27  -8.62    3.08                  0            1
# 10     11  -7.95  -6.44 -4.68   3.86    9.82                  1            0
# ...

# %%
#any(axis=1) checks for whether there is any null value in columns or not
data.isnull().any(axis=1).sum()
# Out:
# 3

# %%
data.dropna(inplace=True)

# %%
data.isnull().any(axis=1).sum()
# Out:
# 0

# %%
data1=pd.get_dummies(data,columns=["CarType"])

# %%
data1.dtypes
# Out:
# CarID                  int64
# ManHI                float64
# ManBI                float64
# IntI                 float64
# HVACi                float64
# Safety               float64
# CarType_Hatchback      uint8
# CarType_SUV            uint8
# dtype: object

# %%
column_list=list(data.columns)

# %%
features=list(set(column_list)-set(['CarType']))

# %%
y=data[['CarType']]

# %%
x=data[features]

# %%
y.shape
# Out:
# (77, 1)

# %%
x.shape
# Out:
# (77, 6)

# %%
pd.get_dummies(y,columns=["CarType"])
# Out:
#     CarType_Hatchback  CarType_SUV
# 0                   0            1
# 1                   1            0
# 2                   1            0
# 3                   1            0
# 4                   0            1
# 5                   0            1
# 6                   1            0
# 7                   1            0
# 8                   1            0
# 9                   0            1
# 10                  1            0
# 11                  0            1
# 12                  0            1
# 13                  1            0
# 15                  1            0
# 16                  1            0
# 17                  1            0
# 18                  0            1
# 19                  0            1
# 20                  0            1
# 22                  1            0
# 23                  1            0
# 24                  0            1
# 25                  1            0
# 26                  1            0
# 27                  1            0
# ...

# %%
test_x=Test_Data[['CarID', 'ManHI', 'ManBI', 'IntI', 'HVACi', 'Safety']]

# %%
test_y=Test_Data[['CarType']]

# %%
prediction=knn.predict(test_x)

# %%
prediction
# Out:
# array(['Hatchback', 'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback',
#        'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback',
#        'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback',
#        'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback', 'Hatchback'],
#       dtype=object)

# %%
pd.get_dummies(test_y,columns=['CarType'])
# Out:
#     CarType_Hatchback  CarType_SUV
# 0                   1            0
# 1                   0            1
# 2                   1            0
# 3                   1            0
# 4                   1            0
# 5                   1            0
# 6                   0            1
# 7                   0            1
# 8                   0            1
# 9                   0            1
# 10                  0            1
# 11                  1            0
# 12                  0            1
# 13                  0            1
# 14                  0            1
# 15                  0            1
# 16                  1            0
# 17                  1            0
# 18                  1            0
# 19                  1            0

# %%
ac=accuracy_score(test_y,prediction)

# %%
ac
# Out:
# 0.5
